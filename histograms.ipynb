# %%
import matplotlib.pyplot as plt
import geopandas as gpd
import numpy as np

# %%
gpkg_path = "outputs/merged_structures.gpkg"
layer_name = "merged_structures"

gdf = gpd.read_file(gpkg_path, layer=layer_name)

# %%
avg_burned_proportion_10m = gdf["burned_proportion_10m"].mean(skipna=True)
print(f"Average burned_proportion_10m: {avg_burned_proportion_10m:.2f}")
# Out:
# Average burned_proportion_10m: 0.62

# %%
avg_burned_proportion_20m = gdf["burned_proportion_20m"].mean(skipna=True)
print(f"Average burned_proportion_20m: {avg_burned_proportion_20m:.2f}")
# Out:
# Average burned_proportion_20m: 0.69

# %%
avg_burned_proportion_50m = gdf["burned_proportion_50m"].mean(skipna=True)
print(f"Average burned_proportion_50m: {avg_burned_proportion_50m:.2f}")
# Out:
# Average burned_proportion_50m: 0.71

# %%
avg_burned_proportion_100m = gdf["burned_proportion_100m"].mean(skipna=True)
print(f"Average burned_proportion_100m: {avg_burned_proportion_100m:.2f}")
# Out:
# Average burned_proportion_100m: 0.71

# %%
# Extract column and drop NaNs
values = gdf["burned_proportion_10m"].dropna()

# Define histogram range (e.g., from min to max rounded to nearest whole number)
min_val = np.floor(values.min())
max_val = np.ceil(values.max())

# Create histogram
plt.figure(figsize=(8, 5))
plt.hist(values, bins=50, edgecolor='black')

plt.xlabel("Mean Burned Proportion")
plt.ylabel("Number of Polygons")
plt.title(" Distribution of Burned Proportion 10m")

plt.xlim(min_val, max_val)
plt.xticks(np.arange(min_val, max_val + 1, 1))
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %%
# Extract column and drop NaNs
values = gdf["burned_proportion_20m"].dropna()

# Define histogram range (e.g., from min to max rounded to nearest whole number)
min_val = np.floor(values.min())
max_val = np.ceil(values.max())

# Create histogram
plt.figure(figsize=(8, 5))
plt.hist(values, bins=50, edgecolor='black')

plt.xlabel("Mean Burned Proportion")
plt.ylabel("Number of Polygons")
plt.title(" Distribution of Burned Proportion 20m")

plt.xlim(min_val, max_val)
plt.xticks(np.arange(min_val, max_val + 1, 1))
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %%
# Extract column and drop NaNs
values = gdf["burned_proportion_50m"].dropna()

# Define histogram range (e.g., from min to max rounded to nearest whole number)
min_val = np.floor(values.min())
max_val = np.ceil(values.max())

# Create histogram
plt.figure(figsize=(8, 5))
plt.hist(values, bins=50, edgecolor='black')

plt.xlabel("Mean Burned Proportion")
plt.ylabel("Number of Polygons")
plt.title(" Distribution of Burned Proportion 50m")

plt.xlim(min_val, max_val)
plt.xticks(np.arange(min_val, max_val + 1, 1))
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %%
# Extract column and drop NaNs
values = gdf["burned_proportion_100m"].dropna()

# Define histogram range (e.g., from min to max rounded to nearest whole number)
min_val = np.floor(values.min())
max_val = np.ceil(values.max())

# Create histogram
plt.figure(figsize=(8, 5))
plt.hist(values, bins=50, edgecolor='black')

plt.xlabel("Mean Burned Proportion")
plt.ylabel("Number of Polygons")
plt.title(" Distribution of Burned Proportion 100m")

plt.xlim(min_val, max_val)
plt.xticks(np.arange(min_val, max_val + 1, 1))
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()
